# %%
import mlflow
mlflow.set_tracking_uri("../mlruns")

# %%
experiment_id = "914879025403898454"
runs = client.search_runs(experiment_ids=[experiment_id])
runs
# Out:
# []

# %%
import mlflow
experiment_id = "914879025403898454"
client = mlflow.tracking.MlflowClient()
runs = client.search_runs(experiment_ids=[
                          experiment_id])
runs
# Out:
# [<Run: data=<RunData: metrics={'aee_attacked_gt': 2.352935314178467,
#   'aee_attacked_gt_step_10': 2.7129242420196533,
#   'aee_attacked_gt_step_15': 3.1639838218688965,
#   'aee_attacked_gt_step_20': 3.246455669403076,
#   'aee_attacked_gt_step_25': 1.2076809406280518,
#   'aee_attacked_gt_step_3': 1.3888423442840576,
#   'aee_attacked_gt_step_30': 2.5843505859375,
#   'aee_attacked_gt_step_35': 2.932650089263916,
#   'aee_attacked_gt_step_40': 2.352935314178467,
#   'aee_attacked_gt_step_5': 2.296868324279785,
#   'aee_gt_step_10': 0.10967980325222015,
#   'aee_gt_step_15': 0.10967980325222015,
#   'aee_gt_step_20': 0.10967980325222015,
#   'aee_gt_step_25': 0.10967980325222015,
#   'aee_gt_step_3': 0.10967980325222015,
#   'aee_gt_step_30': 0.10967980325222015,
#   'aee_gt_step_35': 0.10967980325222015,
#   'aee_gt_step_40': 0.10967980325222015,
#   'aee_gt_step_5': 0.10967980325222015,
#   'aee_init_attack': 23.052322387695312,
#   'aee_init_attack_step_10': 26.55495262145996,
# ...

# %%
run = client.get_run('00a81f4976794db5ad515aa7d03bf5b0')
print(run.data.metrics)
# Out:
# {}

# %%
all_runs = client._list_run_infos()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 all_runs = client._list_run_infos()
#
# AttributeError: 'MlflowClient' object has no attribute '_list_run_infos'
